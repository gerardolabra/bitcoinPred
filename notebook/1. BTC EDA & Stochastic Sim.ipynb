# %% [markdown]
# ### Bitcoin EDA and Stochastic Sim

# %% [markdown]
# #### Import libraries and BTC Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import os

os.chdir('C:/Users/gerar/OneDrive/Documentos/GitHub/bitcoinPred')  # Set the working directory

def load_data(file_path="data/processed/btc_data_processed.csv"):
    """Load the dataset into a pandas DataFrame."""
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"The file {file_path} was not found. Run fetch_data.py first.")
    
    df = pd.read_csv(file_path)
    df["timestamp"] = pd.to_datetime(df["timestamp"])  # Convert timestamps
    return df

def inspect_data(df):
    """Print basic info and statistics."""
    print("First 5 rows:\n", df.head(), "\n")
    print("Data Summary:\n", df.info(), "\n")
    print("Descriptive Statistics:\n", df.describe(), "\n")
    print("Missing Values:\n", df.isnull().sum(), "\n")

if __name__ == "__main__":
    df = load_data()
    inspect_data(df)
# Out:
# First 5 rows:
#     timestamp     open     high      low    close       volume     close_time  \
# 0 2017-09-16  3674.01  3950.00  3470.66  3714.95  1297.563953  1505606399999
# 1 2017-09-17  3685.23  3748.21  3499.02  3699.99   682.171210  1505692799999
# 2 2017-09-18  3690.00  4123.20  3690.00  4035.01  1030.006455  1505779199999
# 3 2017-09-19  4060.00  4089.97  3830.91  3910.04   902.332129  1505865599999
# 4 2017-09-20  3910.04  4046.08  3820.00  3900.00   720.935076  1505951999999
#
#    quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# 0        4.804878e+06              8809                   624.887842
# 1        2.466490e+06              6355                   273.931976
# 2        4.069033e+06              8220                   417.638722
# 3        3.558315e+06              7342                   257.320352
# 4        2.839584e+06              7231                   395.275138
#
#    taker_buy_quote_asset_volume   returns  moving_avg_7  moving_avg_30  \
# 0                  2.314536e+06  0.004041   3864.460000    4239.663667
# 1                  9.948436e+05 -0.004027   3802.977143    4226.051000
# 2                  1.651863e+06  0.090546   3778.197143    4222.552000
# 3                  1.016804e+06 -0.030971   3741.957143    4216.677000
# 4                  1.562210e+06 -0.002568   3735.572857    4212.810333
#
#    volatility_7  volatility_30
# 0      0.104128       0.060268
# 1      0.103943       0.059834
# 2      0.110665       0.062149
# 3      0.111239       0.062376
# 4      0.109144       0.062290
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2762 entries, 0 to 2761
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     2762 non-null   datetime64[ns]
#  1   open                          2762 non-null   float64
#  2   high                          2762 non-null   float64
#  3   low                           2762 non-null   float64
#  4   close                         2762 non-null   float64
#  5   volume                        2762 non-null   float64
#  6   close_time                    2762 non-null   int64
#  7   quote_asset_volume            2762 non-null   float64
#  8   number_of_trades              2762 non-null   int64
#  9   taker_buy_base_asset_volume   2762 non-null   float64
#  10  taker_buy_quote_asset_volume  2762 non-null   float64
#  11  returns                       2762 non-null   float64
#  12  moving_avg_7                  2762 non-null   float64
#  13  moving_avg_30                 2762 non-null   float64
#  14  volatility_7                  2762 non-null   float64
#  15  volatility_30                 2762 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(2)
# memory usage: 345.4 KB
# Data Summary:
#  None
#
# Descriptive Statistics:
#                   timestamp           open           high            low  \
# count                 2762    2762.000000    2762.000000    2762.000000
# mean   2021-06-27 12:00:00   29569.325858   30270.667227   28812.328639
# min    2017-09-16 00:00:00    3211.710000    3276.500000    3156.260000
# 25%    2019-08-07 06:00:00    8822.245000    9060.830000    8567.607500
# 50%    2021-06-27 12:00:00   21778.500000   22449.000000   21240.000000
# 75%    2023-05-18 18:00:00   43985.855000   44970.750000   42970.000000
# max    2025-04-08 00:00:00  106143.820000  109588.000000  105321.490000
# std                    NaN   24814.056140   25334.838243   24255.269796
#
#                close         volume    close_time  quote_asset_volume  \
# count    2762.000000    2762.000000  2.762000e+03        2.762000e+03
# mean    29597.139385   67419.202528  1.624882e+12        1.770056e+09
# min      3211.720000     297.597500  1.505606e+12        1.302533e+06
# 25%      8824.147500   27813.398890  1.565244e+12        3.542668e+08
# 50%     21789.945000   43318.197368  1.624882e+12        1.084462e+09
# 75%     44030.107500   70411.215261  1.684519e+12        2.487424e+09
# max    106143.820000  760705.362783  1.744157e+12        1.746531e+10
# std     24828.089778   79248.831662  6.890103e+10        2.001610e+09
#
#        number_of_trades  taker_buy_base_asset_volume  \
# count      2.762000e+03                  2762.000000
# mean       1.735869e+06                 33506.081363
# min        4.804000e+03                   145.313076
# 25%        3.751105e+05                 13952.811323
# 50%        1.002944e+06                 21500.955123
# 75%        1.950501e+06                 34982.105974
# max        1.522359e+07                374775.574085
# std        2.149484e+06                 39439.755276
#
#        taker_buy_quote_asset_volume      returns   moving_avg_7  \
# count                  2.762000e+03  2762.000000    2762.000000
# mean                   8.757119e+08     0.001795   29513.612095
# min                    6.371469e+05    -0.395048    3317.841429
# 25%                    1.793881e+08    -0.014300    8795.745357
# 50%                    5.257545e+08     0.000716   21905.132143
# 75%                    1.244884e+09     0.016982   43711.021429
# max                    8.783916e+09     0.225014  104036.882857
# std                    9.947185e+08     0.036647   24754.560221
#
#        moving_avg_30  volatility_7  volatility_30
# count    2762.000000   2762.000000    2762.000000
# mean    29181.750515      0.031808       0.034041
# min      3529.849000      0.003054       0.008730
# 25%      8771.331583      0.019362       0.024560
# 50%     21784.817167      0.027871       0.031210
# 75%     43415.107833      0.040209       0.040413
# max    100690.277000      0.176377       0.096093
# std     24447.809766      0.018615       0.014316
#
# Missing Values:
#  timestamp                       0
# open                            0
# high                            0
# low                             0
# close                           0
# volume                          0
# close_time                      0
# quote_asset_volume              0
# number_of_trades                0
# taker_buy_base_asset_volume     0
# taker_buy_quote_asset_volume    0
# returns                         0
# moving_avg_7                    0
# moving_avg_30                   0
# volatility_7                    0
# volatility_30                   0
# dtype: int64

# %% [markdown]
# #### Trading Volume

# %%
def plot_trading_volume(df):
    """Plot trading volume over time."""
    plt.figure(figsize=(12, 6))
    plt.bar(df["timestamp"], df["volume"], color="orange", alpha=0.7)
    plt.xlabel("Date")
    plt.ylabel("Volume")
    plt.title("BTC Trading Volume Over Time")
    plt.show()

if __name__ == "__main__":
    df = load_data()
    plot_trading_volume(df)

# %% [markdown]
# First quarter of 2020 and from mid 2022 to early 2023 BTC Trading Volume peaked.

# %% [markdown]
# #### Returns

# %%
# Ensure the 'returns' column exists
if 'returns' in df.columns:
    # Plot the 'returns' column as a line plot
    plt.figure(figsize=(12, 6))
    plt.plot(df['returns'], label='Returns', color='blue')
    plt.title('Bitcoin Returns Over Time')
    plt.xlabel('Index')
    plt.ylabel('Returns')
    plt.legend()
    plt.grid()
    plt.show()

    # Plot the distribution of returns as a histogram
    plt.figure(figsize=(12, 6))
    plt.hist(df['returns'], bins=50, color='orange', edgecolor='black', alpha=0.7)
    plt.title('Distribution of Bitcoin Returns')
    plt.xlabel('Returns')
    plt.ylabel('Frequency')
    plt.grid()
    plt.show()
else:
    print("The 'returns' column does not exist in the dataset.")

# %% [markdown]
# 2020 was the year where BTC Returns were at its lowest.

# %% [markdown]
# #### MAs and Volatility

# %%
# Convert timestamp to datetime for better visualization
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Plot Moving Averages
plt.figure(figsize=(12, 6))
plt.plot(df['timestamp'], df['close'], label='Close Price', color='blue', alpha=0.5)
plt.plot(df['timestamp'], df['moving_avg_7'], label='7-Day Moving Average', color='orange')
plt.plot(df['timestamp'], df['moving_avg_30'], label='30-Day Moving Average', color='green')
plt.title('Bitcoin Close Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# Plot Volatility
plt.figure(figsize=(12, 6))
plt.plot(df['timestamp'], df['volatility_7'], label='7-Day Volatility', color='red')
plt.plot(df['timestamp'], df['volatility_30'], label='30-Day Volatility', color='purple')
plt.title('Bitcoin Volatility (7-Day and 30-Day)')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Volatility highly influences the price of Bitcoin.

# %% [markdown]
# #### Stochastic Price Sim (GBM)

# %%
# Simulate BTC prices using Geometric Brownian Motion (GBM)

def simulate_btc_prices(df):
    # Last 30 days for params
    recent = df.tail(30)
    S0 = recent['close'].iloc[-1]  # Latest price
    mu = recent['close'].pct_change().mean()  # Drift
    sigma = recent['close'].pct_change().std()  # Volatility

    # Simulation parameters
    T = 30  # 30 days forward
    n_paths = 100
    dt = 1

    # Simulate
    np.random.seed(42)
    prices = np.zeros((T, n_paths))
    prices[0] = S0

    for t in range(1, T):
        rand = np.random.normal(0, 1, n_paths)
        prices[t] = prices[t-1] * np.exp((mu - 0.5 * sigma**2) * dt + sigma * np.sqrt(dt) * rand)

    # Stats
    final_prices = prices[-1]
    drop_prob = np.mean(final_prices < S0 * 0.8) * 100  # Probability of >20% drop
    increase_prob = np.mean(final_prices > S0 * 1.2) * 100  # Probability of >20% increase

    # Plot
    plt.figure(figsize=(14, 7))
    for i in range(n_paths):
        plt.plot(prices[:, i], lw=1, alpha=0.5)
    plt.axhline(S0 * 0.8, color='r', linestyle='--', label='20% Drop')
    plt.axhline(S0 * 1.2, color='g', linestyle='--', label='20% Increase')
    plt.title(f"BTC Price Simulation (S0={S0:.0f}, mu={mu:.4f}, sigma={sigma:.4f})")
    plt.xlabel("Days")
    plt.ylabel("Price (USD)")
    plt.legend()
    plt.show()

    print(f"Probability of >20% drop in 30 days: {drop_prob:.2f}%")
    print(f"Probability of >20% increase in 30 days: {increase_prob:.2f}%")
    return prices

# Run it
sim_prices = simulate_btc_prices(df)
# Out:
# Probability of >20% drop in 30 days: 3.00%
# Probability of >20% increase in 30 days: 15.00%

# %% [markdown]
# GBM formula adapted to BTC data shows the potential pathways of the price.
